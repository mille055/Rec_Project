# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import unidecode
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
def clean_text(text):
    text = unidecode.unidecode(text)
    text = text.replace('\n', ' ')
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', ' ', text, flags=re.MULTILINE)
    # Remove "Sponsored by" phrases
    text = re.sub(r'(?i)sponsored\sby\s\w+', ' ', text)
    # Remove special characters and symbols (excluding spaces)
    text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text)
    # Convert to lowercase
    text = text.lower()
    # Remove extra whitespaces at beginning and end
    text = text.strip()
    return text

# %%
df_podcast = pd.read_pickle('../data/podcast_df_040423.pkl')

# %%
df_podcast.head()
# Out:
#                                                title           producer  \
# 0  One Strange Thing: Paranormal & True-Weird Mys...  One Strange Thing
# 1  One Strange Thing: Paranormal & True-Weird Mys...  One Strange Thing
# 2  One Strange Thing: Paranormal & True-Weird Mys...  One Strange Thing
# 3  One Strange Thing: Paranormal & True-Weird Mys...  One Strange Thing
# 4  One Strange Thing: Paranormal & True-Weird Mys...  One Strange Thing
#
#      genre                                        description  num_episodes  \
# 0  History  Paranormal, unexplainable, and uncanny stories...           105
# 1  History  Paranormal, unexplainable, and uncanny stories...           105
# 2  History  Paranormal, unexplainable, and uncanny stories...           105
# 3  History  Paranormal, unexplainable, and uncanny stories...           105
# 4  History  Paranormal, unexplainable, and uncanny stories...           105
#
#    avg_rating  num_reviews                                               link  \
# 0         4.6        499.0  https://podcasts.apple.com/us/podcast/one-stra...
# 1         4.6        499.0  https://podcasts.apple.com/us/podcast/one-stra...
# 2         4.6        499.0  https://podcasts.apple.com/us/podcast/one-stra...
# 3         4.6        499.0  https://podcasts.apple.com/us/podcast/one-stra...
# 4         4.6        499.0  https://podcasts.apple.com/us/podcast/one-stra...
#
#                                 episode_descriptions   itunes_id  rating  \
# 0  [In celebration of our new premium format—two ...  1526579247       5
# 1  [In celebration of our new premium format—two ...  1526579247       1
# 2  [In celebration of our new premium format—two ...  1526579247       5
# 3  [In celebration of our new premium format—two ...  1526579247       2
# 4  [In celebration of our new premium format—two ...  1526579247       4
#
#           user
# 0  RobinFerris
# 1      Pops.99
# 2    ReddEye81
# 3    Keyta7777
# 4     Okkupent

# %%
df_podcast_clean = df_podcast.drop_duplicates(subset=["itunes_id"],keep="first").reset_index(drop=True)
df_podcast_clean['description'] = df_podcast_clean['description'].apply(clean_text)

# %%
df_podcast_clean.head()
# Out:
#                                                title              producer  \
# 0  One Strange Thing: Paranormal & True-Weird Mys...     One Strange Thing
# 1                                       BibleProject  BibleProject Podcast
# 2                        The Domonique Foxworth Show                  ESPN
# 3                                     Hacking Humans        CyberWire Inc.
# 4                                          Leader Up                  AMSC
#
#                      genre                                        description  \
# 0                  History  paranormal  unexplainable  and uncanny stories...
# 1  Religion & Spirituality  the creators of bibleproject have in depth con...
# 2                   Sports  with episodes every tuesday and thursday durin...
# 3               Technology  deception  influence  and social engineering i...
# 4               Government  leader up  a podcast by the army management st...
#
#    num_episodes  avg_rating  num_reviews  \
# 0           105         4.6        499.0
# 1           352         4.9      15000.0
# 2            70         4.9       1100.0
# 3           415         4.7        255.0
# 4            52         5.0         14.0
#
#                                                 link  \
# 0  https://podcasts.apple.com/us/podcast/one-stra...
# 1  https://podcasts.apple.com/us/podcast/biblepro...
# 2  https://podcasts.apple.com/us/podcast/the-domo...
# 3  https://podcasts.apple.com/us/podcast/hacking-...
# 4  https://podcasts.apple.com/us/podcast/leader-u...
#
#                                 episode_descriptions   itunes_id  rating  \
# 0  [In celebration of our new premium format—two ...  1526579247       5
# 1  [David was Israel’s greatest king, but even he...  1050832450       5
# 2  [Domonique, Charlie, and Ashley Foxworth along...  1642566714       5
# 3  [Kathleen Smith, CMO from ClearedJobs.Net sits...  1391915810       5
# 4  [MSC's Mr. David Howey meets with CSM Jason C....  1378682853       5
#
#                   user
# 0          RobinFerris
# 1            nina52475
# 2  nick ndd as mm name
# 3       FreshDoughnuts
# 4     Nolikeynewudatey

# %%
df_podcast_clean.iloc[2,:]['description']
# Out:
# 'with episodes every tuesday and thursday during the football season  espn and andscape contributor domonique foxworth debuts his new podcast featuring his unique perspectives on football  the personalities surrounding it  and just about anything else he finds interesting or thinks you might  you ll'

# %%
wordnet_lemmatizer = WordNetLemmatizer()
stopwords = stopwords.words('english')
df_podcast_clean['description_tokens'] = df_podcast_clean['description'].apply(word_tokenize)
df_podcast_clean['description_tokens'] = df_podcast_clean['description_tokens'].apply(lambda x: [word for word in x if word not in stopwords])
df_podcast_clean['description_lemma'] = df_podcast_clean['description_tokens'].apply(lambda x: [wordnet_lemmatizer.lemmatize(word) for word in x])
df_podcast_clean['description_tokens'] = df_podcast_clean['description_tokens'].apply(lambda x: " ".join(x))
df_podcast_clean = df_podcast_clean.drop(columns=['description_lemma'])

# %%
df_podcast_clean.head()
# Out:
#                                                title              producer  \
# 0  One Strange Thing: Paranormal & True-Weird Mys...     One Strange Thing
# 1                                       BibleProject  BibleProject Podcast
# 2                        The Domonique Foxworth Show                  ESPN
# 3                                     Hacking Humans        CyberWire Inc.
# 4                                          Leader Up                  AMSC
#
#                      genre                                        description  \
# 0                  History  paranormal  unexplainable  and uncanny stories...
# 1  Religion & Spirituality  the creators of bibleproject have in depth con...
# 2                   Sports  with episodes every tuesday and thursday durin...
# 3               Technology  deception  influence  and social engineering i...
# 4               Government  leader up  a podcast by the army management st...
#
#    num_episodes  avg_rating  num_reviews  \
# 0           105         4.6        499.0
# 1           352         4.9      15000.0
# 2            70         4.9       1100.0
# 3           415         4.7        255.0
# 4            52         5.0         14.0
#
#                                                 link  \
# 0  https://podcasts.apple.com/us/podcast/one-stra...
# 1  https://podcasts.apple.com/us/podcast/biblepro...
# 2  https://podcasts.apple.com/us/podcast/the-domo...
# 3  https://podcasts.apple.com/us/podcast/hacking-...
# 4  https://podcasts.apple.com/us/podcast/leader-u...
#
#                                 episode_descriptions   itunes_id  rating  \
# 0  [In celebration of our new premium format—two ...  1526579247       5
# 1  [David was Israel’s greatest king, but even he...  1050832450       5
# 2  [Domonique, Charlie, and Ashley Foxworth along...  1642566714       5
# 3  [Kathleen Smith, CMO from ClearedJobs.Net sits...  1391915810       5
# 4  [MSC's Mr. David Howey meets with CSM Jason C....  1378682853       5
#
#                   user                                 description_tokens
# 0          RobinFerris  paranormal unexplainable uncanny stories ficti...
# 1            nina52475  creators bibleproject depth conversations bibl...
# 2  nick ndd as mm name  episodes every tuesday thursday football seaso...
# 3       FreshDoughnuts  deception influence social engineering world c...
# 4     Nolikeynewudatey  leader podcast army management staff college a...

# %%
df_podcast_clean.to_pickle('../data/podcast_df_tokens_040723.pkl')

# %%
# Create vocabulary
vocabulary = set()
for tokens in df_podcast_clean['description_tokens']:
    vocabulary.update(tokens.split())
vocabulary = list(vocabulary)
# Create TF-IDF model
tfidf = TfidfVectorizer(vocabulary=vocabulary)
tfidf.fit(df_podcast_clean['description_tokens'])
tfidf_matrix = tfidf.transform(df_podcast_clean['description_tokens'])

# %%
def gen_vector_T(tokens):
    Q = np.zeros((len(vocabulary)))    
    x = tfidf.transform(tokens)
    for token in tokens[0].split():
        try:
            ind = vocabulary.index(token)
            Q[ind]  = x[0, tfidf.vocabulary_[token]]
        except:
            pass
    return Q

# %%
def cosine_sim(a, b):
    cos_sim = np.dot(a, b)/(np.linalg.norm(a)*np.linalg.norm(b))
    return cos_sim

# %%
def cosine_similarity_T(k, query):
    preprocessed_query = re.sub("\W+", " ", query).strip()
    tokens = word_tokenize(str(preprocessed_query))
    q_df = pd.DataFrame(columns=['q_clean'])
    q_df.loc[0, 'q_clean'] = tokens
    q_df['q_clean'] = q_df['q_clean'].apply(lambda x: [wordnet_lemmatizer.lemmatize(word) for word in x])
    q_df['q_clean'] = q_df['q_clean'].apply(lambda x: " ".join(x))
    d_cosines = []

    query_vector = gen_vector_T(q_df['q_clean'])
    for d in tfidf_matrix.A:
        d_cosines.append(cosine_sim(query_vector, d))

    out = np.array(d_cosines).argsort()[-k:][::-1]
    d_cosines.sort()
    a = pd.DataFrame()
    for i, index in enumerate(out):
        a.loc[i,'index'] = str(index)
        a.loc[i,'Podcast'] = df_podcast_clean['title'][index]
        a.loc[i,'Genre'] = df_podcast_clean['genre'][index]
    for j,simScore in enumerate(d_cosines[-k:][::-1]):
        a.loc[j,'Score'] = simScore
    return a

# %%
cosine_similarity_T(10, 'healthy recipes')
# Out:
#   index                                    Podcast             Genre     Score
# 0  1604                           Play Me a Recipe              Arts  0.346577
# 1   161                             The One Recipe              Arts  0.323912
# 2  1051                           Life Kit: Health           Science  0.169684
# 3  3523                        The Laughing Couple     Kids & Family  0.164483
# 4  3014                                      Proof              Arts  0.157306
# 5  3088                                Recipe Club              Arts  0.156601
# 6  2309                                Crime Salad        True Crime  0.155852
# 7  1415                        She's My Cherry Pie              Arts  0.141460
# 8   562               The Checkup with Doctor Mike  Health & Fitness  0.124995
# 9   167  Fundamental Health with Paul Saladino, MD  Health & Fitness  0.123285

# %%
cosine_similarity_T(10, 'machine learning')
# Out:
#   index                                            Podcast       Genre  \
# 0   536                     Adventures in Machine Learning  Technology
# 1   581                                   Machine Learning  Technology
# 2  2224                                   Gradient Dissent  Technology
# 3   915                                            ChatGPT        News
# 4  3263                Private Pilot Podcast by MzeroA.com     Leisure
# 5  2229       Practical AI: Machine Learning, Data Science  Technology
# 6  1890                                       Data Skeptic  Technology
# 7   321                                 Super Data Science  Technology
# 8    91                                News in Slow French   Education
# 9   415  The TWIML AI Podcast (formerly This Week in Ma...  Technology
#
#       Score
# 0  0.577918
# 1  0.394043
# 2  0.380504
# 3  0.311805
# 4  0.296127
# 5  0.265195
# 6  0.254437
# 7  0.246207
# 8  0.242155
# 9  0.216544

# %%
cosine_similarity_T(10, 'god and christianity')
# Out:
#   index                                            Podcast  \
# 0  3461           Questioning Christianity with Tim Keller
# 1  3588                         The Alisa Childers Podcast
# 2  2060        Compelled - Christian Stories & Testimonies
# 3  2741         I Don't Have Enough FAITH to Be an ATHEIST
# 4  2393                  Bethel Redding Sermon of the Week
# 5  2322                             The Russell Moore Show
# 6  2335                                Heaven In Your Home
# 7  2358                 Daily Drive with Lakepointe Church
# 8  1208  Hearing Jesus: Daily Bible Study, Daily Devoti...
# 9  2277                                Blessed + Bossed Up
#
#                      Genre     Score
# 0  Religion & Spirituality  0.335481
# 1  Religion & Spirituality  0.283445
# 2  Religion & Spirituality  0.271950
# 3  Religion & Spirituality  0.255668
# 4  Religion & Spirituality  0.229422
# 5  Religion & Spirituality  0.193257
# 6  Religion & Spirituality  0.189199
# 7  Religion & Spirituality  0.186813
# 8  Religion & Spirituality  0.184402
# 9                 Business  0.177282

# %%
cosine_similarity_T(10, 'american football')
# Out:
#   index                                            Podcast       Genre  \
# 0   981                                   Legendary Upside      Sports
# 1  3805                The Mina Kimes Show featuring Lenny      Sports
# 2  1057     Fantasy Footballers - Fantasy Football Podcast      Sports
# 3     2                        The Domonique Foxworth Show      Sports
# 4  1332               FantasyPros Dynasty Football Podcast      Sports
# 5  2161                               American Contingency  Government
# 6  3425  The Andy Staples Show & Friends: A show about ...      Sports
# 7  3208   The Athletic Football Show: A show about the NFL      Sports
# 8   862                            This American President     History
# 9   693  Fantasy Footballers Dynasty - Fantasy Football...      Sports
#
#       Score
# 0  0.314015
# 1  0.313506
# 2  0.295500
# 3  0.287226
# 4  0.253914
# 5  0.247415
# 6  0.246131
# 7  0.238489
# 8  0.207673
# 9  0.201617

# %%
cosine_similarity_T(10, 'ghost and haunted houses')
# Out:
#   index                                            Podcast              Genre  \
# 0  3196                  The Night Owl: True Ghost Stories  Society & Culture
# 1  2067                                       Haunted Road         True Crime
# 2  2895  Deeper Shades of House - weekly Deep House Pod...              Music
# 3  1463                                    GraveYard Tales            Science
# 4   489                     True Hauntings & Scary Stories            Fiction
# 5   462  Ghost Town: Strange History, True Crime, & the...            History
# 6   957                                     The Witch Farm            Fiction
# 7   575                              Jim Harold's Campfire  Society & Culture
# 8  1067                                   Chapo Trap House               News
# 9    75                                    In Another Room            Fiction
#
#       Score
# 0  0.519754
# 1  0.273631
# 2  0.259715
# 3  0.250926
# 4  0.226258
# 5  0.224307
# 6  0.224033
# 7  0.221682
# 8  0.217150
# 9  0.208114
